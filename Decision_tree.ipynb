# %% [markdown]
# <a href="https://colab.research.google.com/github/issack123/issack123/blob/main/Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

import pandas as pd

# %%
df = pd.read_csv(r"/content/sonar.csv")
df.head()
# Out:
#       CO1     CO2     CO3     CO4  ...    CO58    CO59    CO60  target1
# 0  0.0200  0.0371  0.0428  0.0207  ...  0.0084  0.0090  0.0032        R
# 1  0.0453  0.0523  0.0843  0.0689  ...  0.0049  0.0052  0.0044        R
# 2  0.0262  0.0582  0.1099  0.1083  ...  0.0164  0.0095  0.0078        R
# 3  0.0100  0.0171  0.0623  0.0205  ...  0.0044  0.0040  0.0117        R
# 4  0.0762  0.0666  0.0481  0.0394  ...  0.0048  0.0107  0.0094        R
#
# [5 rows x 61 columns]

# %%
df.describe()
# Out:
#               CO1         CO2         CO3  ...        CO58        CO59        CO60
# count  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832  ...    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428  ...    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950  ...    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300  ...    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950  ...    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
df.hist()
plt.show()

# %%
print(df.shape)
# Out:
# (208, 61)

# %%
x = df.drop("target1", axis=1)
y = df['target1'].copy()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state = 40)

# %%
x_train.shape
# Out:
# (156, 60)

# %%
x_test.shape
# Out:
# (52, 60)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print("Accuracy of DT is:", accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy of DT is: 75.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[24  8]
#  [ 5 15]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            M       0.83      0.75      0.79        32
#            R       0.65      0.75      0.70        20
#
#     accuracy                           0.75        52
#    macro avg       0.74      0.75      0.74        52
# weighted avg       0.76      0.75      0.75        52
